# %% [markdown]
# # 빅데이터 분석기사 예제

# %% [markdown]
# # 작업형 1유형 예시문제
#
# * mtcars 데이터셋의 qsec 컬럼을 최소최대 척도(Min Max Scale)로 변환한 후 0.5 보다 큰 값을 가지는 레코드 수를 구하시오.

# %%
import pandas as pd

# %%
df_mtcars= pd.read_csv('mtcars.csv')
df_mtcars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler() 
df_mtcars_qsec_minmax = scaler.fit_transform(df_mtcars[['qsec']])

# %%
import numpy as np
np.sum(df_mtcars_qsec_minmax>0.5)
# Out:
# 9

# %%
print(np.sum(df_mtcars_qsec_minmax>0.5))
# Out:
# 9

# %% [markdown]
# # 2. 작업형 제2유형 : 모형 구축 및 평가 영역
# - 고객 3,500명에 대한 학습용 데이터(y_train.csv, X_train.csv)를 이용하여 성별예측 모형을 만든 후, 이를 평가용 데이터(X_test.csv)에 적용하여 얻은 2,482명 고객의 성별 예측값(남자일 확률 = gender:1)을 다음과 같은 형식의 CSV 파일로 생성하시오.(제출한 모델의 성능은 ROC-AUC 평가지표에 따라 채점)

# %%
X_train = pd.read_csv('X_train.csv',encoding='cp949')
y_train = pd.read_csv('y_train.csv',encoding='cp949')
X_test = pd.read_csv('X_test.csv',encoding='cp949')

# %%
X_train.set_index('cust_id',inplace=True)

# %%
y_train.set_index('cust_id',inplace=True)
X_test.set_index('cust_id',inplace=True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3500 entries, 0 to 3499
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   총구매액     3500 non-null   int64
#  1   최대구매액    3500 non-null   int64
#  2   환불금액     1205 non-null   float64
#  3   주구매상품    3500 non-null   object
#  4   주구매지점    3500 non-null   object
#  5   내점일수     3500 non-null   int64
#  6   내점당구매건수  3500 non-null   float64
#  7   주말방문비율   3500 non-null   float64
#  8   구매주기     3500 non-null   int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 273.4+ KB

# %%
X_train.describe()
# Out:
#                총구매액         최대구매액          환불금액         내점일수      내점당구매건수  \
# count  3.500000e+03  3.500000e+03  1.205000e+03  3500.000000  3500.000000
# mean   9.191925e+07  1.966424e+07  2.407822e+07    19.253714     2.834963
# std    1.635065e+08  3.199235e+07  4.746453e+07    27.174942     1.912368
# min   -5.242152e+07 -2.992000e+06  5.600000e+03     1.000000     1.000000
# 25%    4.747050e+06  2.875000e+06  2.259000e+06     2.000000     1.666667
# 50%    2.822270e+07  9.837000e+06  7.392000e+06     8.000000     2.333333
# 75%    1.065079e+08  2.296250e+07  2.412000e+07    25.000000     3.375000
# max    2.323180e+09  7.066290e+08  5.637530e+08   285.000000    22.083333
#
#             주말방문비율         구매주기
# count  3500.000000  3500.000000
# mean      0.307246    20.958286
# std       0.289752    24.748682
# min       0.000000     0.000000
# 25%       0.027291     4.000000
# 50%       0.256410    13.000000
# 75%       0.448980    28.000000
# max       1.000000   166.000000

# %%
X_train.boxplot()
# Out:
# <AxesSubplot:>

# %%
X_train
# Out:
#               총구매액     최대구매액       환불금액   주구매상품 주구매지점  내점일수   내점당구매건수  \
# cust_id
# 0         68282840  11264000  6860000.0      기타   강남점    19  3.894737
# 1          2136000   2136000   300000.0     스포츠   잠실점     2  1.500000
# 2          3197000   1639000        NaN  남성 캐주얼   관악점     2  2.000000
# 3         16077620   4935000        NaN      기타   광주점    18  2.444444
# 4         29050000  24000000        NaN      보석  본  점     2  1.500000
# ...            ...       ...        ...     ...   ...   ...       ...
# 3495       3175200   3042900        NaN      골프  본  점     1  2.000000
# 3496      29628600   7200000  6049600.0    시티웨어  부산본점     8  1.625000
# 3497         75000     75000        NaN    주방용품   창원점     1  1.000000
# 3498       1875000   1000000        NaN     화장품  본  점     2  1.000000
# 3499     263101550  34632000  5973000.0      기타  본  점    38  2.421053
#
#            주말방문비율  구매주기
# cust_id
# 0        0.527027    17
# 1        0.000000     1
# 2        0.000000     1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train = pd.get_dummies(X_train, columns=['주구매지점','주구매상품'])

# %%
X_train['환불금액'] = X_train['환불금액'].fillna(0)

# %%
clf = RandomForestClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# C:\Users\jjang\anaconda3\envs\ADP_Class\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier()

# %%
X_train.shape
# Out:
# (3500, 73)

# %%
X_test.shape
# Out:
# (2482, 72)

# %%
X_test = pd.get_dummies(X_test, columns=['주구매상품','주구매지점'])

# %%
X_test['환불금액'] = X_test['환불금액'].fillna(0)

# %%
X_train.columns[X_train.columns.isin(X_test.columns)==False]
# Out:
# Index(['주구매상품_소형가전'], dtype='object')

# %%
X_test['주구매상품_소형가전'] = 0

# %%
X_test.shape
# Out:
# (2482, 73)

# %%
pd.DataFrame(clf.predict_proba(X_test)[:,1]).to_csv("predict.csv")
# Out:
#          0
# 0     0.37
# 1     0.23
# 2     0.27
# 3     0.38
# 4     0.53
# ...    ...
# 2477  0.48
# 2478  0.65
# 2479  0.47
# 2480  0.36
# 2481  0.41
#
# [2482 rows x 1 columns]
