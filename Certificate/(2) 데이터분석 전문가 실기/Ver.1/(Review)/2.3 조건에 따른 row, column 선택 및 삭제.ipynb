# %%
import pandas as pd
import numpy as np

df_t = pd.read_csv('../data/titanic.csv')
df_t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male  embark_town
# 0        True  Southampton
# 1       False    Cherbourg
# 2       False  Southampton
# 3       False  Southampton
# 4        True  Southampton

# %%
df_t[df_t['survived'] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#      adult_male  embark_town
# 1         False    Cherbourg
# 2         False  Southampton
# 3         False  Southampton
# 8         False  Southampton
# 9         False    Cherbourg
# ..          ...          ...
# 875       False    Cherbourg
# 879       False    Cherbourg
# 880       False  Southampton
# 887       False  Southampton
# 889        True    Cherbourg
#
# [342 rows x 11 columns]

# %%
df_t['survived'] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: survived, Length: 891, dtype: bool

# %%
df_t[ (df_t['survived'] == 1) | (df_t['fare'] > 30) & (df_t['class'] == 'First') ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#      adult_male  embark_town
# 1         False    Cherbourg
# 2         False  Southampton
# 3         False  Southampton
# 6          True  Southampton
# 8         False  Southampton
# ..          ...          ...
# 875       False    Cherbourg
# 879       False    Cherbourg
# 880       False  Southampton
# 887       False  Southampton
# 889        True    Cherbourg
#
# [396 rows x 11 columns]

# %%
df_t.loc[df_t['survived'] == 1, 'temp'] = 9999
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town    temp
# 0          True  Southampton     NaN
# 1         False    Cherbourg  9999.0
# 2         False  Southampton  9999.0
# 3         False  Southampton  9999.0
# 4          True  Southampton     NaN
# ..          ...          ...     ...
# 886        True  Southampton     NaN
# 887       False  Southampton  9999.0
# 888       False  Southampton     NaN
# 889        True    Cherbourg  9999.0
# 890        True   Queenstown     NaN
#
# [891 rows x 12 columns]

# %%
df_t['temp2'] = False
df_t.loc[df_t.age>30, 'temp2']
# Out:
# 1      False
# 3      False
# 4      False
# 6      False
# 11     False
#        ...
# 873    False
# 879    False
# 881    False
# 885    False
# 890    False
# Name: temp2, Length: 305, dtype: bool

# %%
df_t.loc[df_t.age>30, 'temp2'] = '30대 이상입니다.'

# %%
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town    temp       temp2
# 0          True  Southampton     NaN       False
# 1         False    Cherbourg  9999.0  30대 이상입니다.
# 2         False  Southampton  9999.0       False
# 3         False  Southampton  9999.0  30대 이상입니다.
# 4          True  Southampton     NaN  30대 이상입니다.
# ..          ...          ...     ...         ...
# 886        True  Southampton     NaN       False
# 887       False  Southampton  9999.0       False
# 888       False  Southampton     NaN       False
# 889        True    Cherbourg  9999.0       False
# 890        True   Queenstown     NaN  30대 이상입니다.
#
# [891 rows x 13 columns]

# %%
df_t[df_t['age'] > 30]['temp2'] = True
# Out:
# <ipython-input-10-a8a623290e85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t[df_t['age'] > 30]['temp2'] = True

# %%
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town    temp       temp2
# 0          True  Southampton     NaN       False
# 1         False    Cherbourg  9999.0  30대 이상입니다.
# 2         False  Southampton  9999.0       False
# 3         False  Southampton  9999.0  30대 이상입니다.
# 4          True  Southampton     NaN  30대 이상입니다.
# ..          ...          ...     ...         ...
# 886        True  Southampton     NaN       False
# 887       False  Southampton  9999.0       False
# 888       False  Southampton     NaN       False
# 889        True    Cherbourg  9999.0       False
# 890        True   Queenstown     NaN  30대 이상입니다.
#
# [891 rows x 13 columns]

# %%
df_t[df_t['age'] > 30].temp2
# Out:
# 1      30대 이상입니다.
# 3      30대 이상입니다.
# 4      30대 이상입니다.
# 6      30대 이상입니다.
# 11     30대 이상입니다.
#           ...
# 873    30대 이상입니다.
# 879    30대 이상입니다.
# 881    30대 이상입니다.
# 885    30대 이상입니다.
# 890    30대 이상입니다.
# Name: temp2, Length: 305, dtype: object

# %%
df_t.loc[df_t['age'] > 30, 'temp2'] = True

# %%
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town    temp  temp2
# 0          True  Southampton     NaN  False
# 1         False    Cherbourg  9999.0   True
# 2         False  Southampton  9999.0  False
# 3         False  Southampton  9999.0   True
# 4          True  Southampton     NaN   True
# ..          ...          ...     ...    ...
# 886        True  Southampton     NaN  False
# 887       False  Southampton  9999.0  False
# 888       False  Southampton     NaN  False
# 889        True    Cherbourg  9999.0  False
# 890        True   Queenstown     NaN   True
#
# [891 rows x 13 columns]

# %%
df_t.drop(columns = ['temp', 'temp2'], inplace = True)

# %%
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town
# 0          True  Southampton
# 1         False    Cherbourg
# 2         False  Southampton
# 3         False  Southampton
# 4          True  Southampton
# ..          ...          ...
# 886        True  Southampton
# 887       False  Southampton
# 888       False  Southampton
# 889        True    Cherbourg
# 890        True   Queenstown
#
# [891 rows x 11 columns]

# %%
df_t['alive'] = np.where(df_t['survived'] == 1, 'Yes', 'No')
df_t.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town alive
# 0        True  Southampton    No
# 1       False    Cherbourg   Yes
# 2       False  Southampton   Yes
# 3       False  Southampton   Yes
# 4        True  Southampton    No
# 5        True   Queenstown    No
# 6        True  Southampton    No
# 7       False  Southampton    No
# 8       False  Southampton   Yes
# 9       False    Cherbourg   Yes

# %%
conditionlist = [
    (df_t['age'] >= 19),
    (df_t['age'] >= 8) & (df_t['age'] < 19),
    df_t['age'] < 8
]

choicelist = ['성인', '초중고등학생', '미취학아동']

df_t['status'] = np.select(conditionlist, choicelist, default = 'Not_Specified')

df_t.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#    adult_male  embark_town alive         status
# 0        True  Southampton    No             성인
# 1       False    Cherbourg   Yes             성인
# 2       False  Southampton   Yes             성인
# 3       False  Southampton   Yes             성인
# 4        True  Southampton    No             성인
# 5        True   Queenstown    No  Not_Specified
# 6        True  Southampton    No             성인
# 7       False  Southampton    No          미취학아동
# 8       False  Southampton   Yes             성인
# 9       False    Cherbourg   Yes         초중고등학생
