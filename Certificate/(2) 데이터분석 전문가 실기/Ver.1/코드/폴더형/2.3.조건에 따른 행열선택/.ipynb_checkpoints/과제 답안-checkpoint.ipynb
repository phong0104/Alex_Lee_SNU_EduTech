# %%
## 과제 2 

## 세종시 주택 가격 table에서

# %%
import pandas as pd 
import numpy as np

# %%
df_sejong = pd.read_csv("세종시_아파트(전월세)_실거래가.csv",encoding='utf8')

# %%
df_sejong.columns
# Out:
# Index(['Unnamed: 0', '계약년월', '계약일', '시군구', '본번', '부번', '단지명', '전월세구분',
#        '전용면적(㎡)', '보증금(만원)', '월세(만원)', '층', '건축년도'],
#       dtype='object')

# %%
df_sejong = df_sejong.drop(columns='Unnamed: 0')

# %%
df_sejong.전월세구분.unique()
# Out:
# array(['전세', '월세'], dtype=object)

# %%
## 전월세 구분 중 unique 값을 찾고, 전세만 추출 
df_sejong[df_sejong['전월세구분']=='전세']
# Out:
#          계약년월  계약일          시군구    본번  부번                  단지명 전월세구분  \
# 0      201701   13  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 1      201701   14  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 2      201701   14  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 3      201701   15  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 5      201702    8  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# ...       ...  ...          ...   ...  ..                  ...   ...
# 38887  202011    9  세종특별자치시 해밀동  6402   1             해밀마을 2단지    전세
# 38888  202011   14  세종특별자치시 해밀동  6402   1             해밀마을 2단지    전세
# 38889  202011   14  세종특별자치시 해밀동  6402   1             해밀마을 2단지    전세
# 38892  202012   11  세종특별자치시 해밀동  6402   1             해밀마을 2단지    전세
# 38893  202012   12  세종특별자치시 해밀동  6402   1             해밀마을 2단지    전세
#
#         전용면적(㎡)  보증금(만원)  월세(만원)   층  건축년도
# 0       84.9895    10000       0  13  2015
# 1       84.9895    18000       0  19  2015
# ...

# %%
## 원본데이터에서 단지명 중  해밀마을 2단지인 row 삭제

# %%
df_sejong.drop(df_sejong[df_sejong['단지명']=='해밀마을 2단지'].index)
# Out:
#          계약년월  계약일          시군구    본번  부번                  단지명 전월세구분  전용면적(㎡)  \
# 0      201701   13  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세  84.9895
# 1      201701   14  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세  84.9895
# 2      201701   14  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세  59.8338
# 3      201701   15  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세  84.9895
# 4      201702    4  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    월세  84.9895
# ...       ...  ...          ...   ...  ..                  ...   ...      ...
# 38852  202012    6  세종특별자치시 해밀동  6401   1             해밀마을 1단지    월세  59.4000
# 38853  202012    8  세종특별자치시 해밀동  6401   1             해밀마을 1단지    월세  59.4000
# 38854  202012   11  세종특별자치시 해밀동  6401   1             해밀마을 1단지    전세  84.8500
# 38855  202012   13  세종특별자치시 해밀동  6401   1             해밀마을 1단지    월세  84.8500
# 38856  202012   19  세종특별자치시 해밀동  6401   1             해밀마을 1단지    전세  84.6700
#
#        보증금(만원)  월세(만원)   층  건축년도
# ...

# %%
##새로운 컬럼에 신규 시군구 컬럼을 만들고 '세종특별자치시 고운동' => '세종특별자치시 해밀동' 으로 변경

# %%
df_sejong.시군구.unique()
# Out:
# array(['세종특별자치시 고운동', '세종특별자치시 금남면 용포리', '세종특별자치시 나성동', '세종특별자치시 다정동',
#        '세종특별자치시 대평동', '세종특별자치시 도담동', '세종특별자치시 반곡동', '세종특별자치시 보람동',
#        '세종특별자치시 부강면 부강리', '세종특별자치시 새롬동', '세종특별자치시 소담동', '세종특별자치시 아름동',
#        '세종특별자치시 어진동', '세종특별자치시 연동면 명학리', '세종특별자치시 연서면 봉암리',
#        '세종특별자치시 장군면 금암리', '세종특별자치시 전동면 노장리', '세종특별자치시 전의면 동교리',
#        '세종특별자치시 전의면 유천리', '세종특별자치시 조치원읍 교리', '세종특별자치시 조치원읍 남리',
#        '세종특별자치시 조치원읍 번암리', '세종특별자치시 조치원읍 상리', '세종특별자치시 조치원읍 신안리',
#        '세종특별자치시 조치원읍 신흥리', '세종특별자치시 조치원읍 원리', '세종특별자치시 조치원읍 정리',
#        '세종특별자치시 조치원읍 죽림리', '세종특별자치시 조치원읍 침산리', '세종특별자치시 종촌동',
#        '세종특별자치시 한솔동', '세종특별자치시 소정면 운당리', '세종특별자치시 조치원읍 서창리',
#        '세종특별자치시 해밀동'], dtype=object)

# %%
df_sejong['new_시군구'] = df_sejong['시군구']

# %%
df_sejong['new_시군구'].unique()
# Out:
# array(['세종특별자치시 고운동', '세종특별자치시 금남면 용포리', '세종특별자치시 나성동', '세종특별자치시 다정동',
#        '세종특별자치시 대평동', '세종특별자치시 도담동', '세종특별자치시 반곡동', '세종특별자치시 보람동',
#        '세종특별자치시 부강면 부강리', '세종특별자치시 새롬동', '세종특별자치시 소담동', '세종특별자치시 아름동',
#        '세종특별자치시 어진동', '세종특별자치시 연동면 명학리', '세종특별자치시 연서면 봉암리',
#        '세종특별자치시 장군면 금암리', '세종특별자치시 전동면 노장리', '세종특별자치시 전의면 동교리',
#        '세종특별자치시 전의면 유천리', '세종특별자치시 조치원읍 교리', '세종특별자치시 조치원읍 남리',
#        '세종특별자치시 조치원읍 번암리', '세종특별자치시 조치원읍 상리', '세종특별자치시 조치원읍 신안리',
#        '세종특별자치시 조치원읍 신흥리', '세종특별자치시 조치원읍 원리', '세종특별자치시 조치원읍 정리',
#        '세종특별자치시 조치원읍 죽림리', '세종특별자치시 조치원읍 침산리', '세종특별자치시 종촌동',
#        '세종특별자치시 한솔동', '세종특별자치시 소정면 운당리', '세종특별자치시 조치원읍 서창리',
#        '세종특별자치시 해밀동'], dtype=object)

# %%
df_sejong.loc[(df_sejong['시군구'] == '세종특별자치시 고운동'), 'new_시군구'] = '세종특별자치시 해밀동'

# %%
'세종특별자치시 고운동' in df_sejong['new_시군구'].unique()
# Out:
# False

# %%
## 전세구분 컬럼을 생성한 뒤, 전세면 True 아니면 False

# %%
df_sejong['전세구분'] = False

# %%
df_sejong.loc[df_sejong['전월세구분'] =='전세','전세구분'] = True

# %%
df_sejong
# Out:
#          계약년월  계약일          시군구    본번  부번                  단지명 전월세구분  \
# 0      201701   13  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 1      201701   14  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 2      201701   14  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 3      201701   15  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    전세
# 4      201702    4  세종특별자치시 고운동  1396   0  가락마을 20단지(호반베르디움5차)    월세
# ...       ...  ...          ...   ...  ..                  ...   ...
# 38890  202011   21  세종특별자치시 해밀동  6402   1             해밀마을 2단지    월세
# 38891  202012    8  세종특별자치시 해밀동  6402   1             해밀마을 2단지    월세
# 38892  202012   11  세종특별자치시 해밀동  6402   1             해밀마을 2단지    전세
# 38893  202012   12  세종특별자치시 해밀동  6402   1             해밀마을 2단지    전세
# 38894  202012   13  세종특별자치시 해밀동  6402   1             해밀마을 2단지    월세
#
#         전용면적(㎡)  보증금(만원)  월세(만원)   층  건축년도      new_시군구   전세구분
# 0       84.9895    10000       0  13  2015  세종특별자치시 해밀동   True
# ...

# %%
## 과제 3 ser1과 ser2의 공통되지 않은 값만 ser3에저장 
ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])

# %%
ser3 = ser1.append(ser2).reset_index(drop=True)
drop_index = ser3[ser3.isin(ser3[ser3.duplicated()==True])].index
ser3.drop(drop_index)

# %%
# Out:
# 0    1
# 1    2
# 2    3
# 7    6
# 8    7
# 9    8
# dtype: int64
