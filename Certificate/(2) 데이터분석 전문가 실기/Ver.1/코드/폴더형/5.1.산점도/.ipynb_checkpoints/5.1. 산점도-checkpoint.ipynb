# %% [markdown]
# # 산점도
#
# - 두 개의 연속형 변수간의 관계를 알아볼 수 있도록 좌표평면 상에 관측점을 찍어 나타낸 그래프
# - 좌표형면 상의 관측점은 두 변수를 의미하는 x, y의 점으로 나타냄

# %% [markdown]
# 산점도 그리기 기본
# - plt.scatter(x, y, c, s, alpha)
#     - x, y : x축과 y축
#     - c: 색
#     - s: 마커의 면적
#     - alpha: 마커색의 투명도

# %%
import sklearn

# %%
sklearn.preprocessing.MinMaxScaler

# %% [markdown]
# __[예제]__
# cars93데이터의 length와 weight 변수에 대한 산점도 그리기

# %%
# 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 


cars = pd.read_csv("Cars93.csv")
cars
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0            31                None      Front  ...          5     177
# 1            25  Driver & Passenger      Front  ...          5     195
# 2            26         Driver only      Front  ...          5     180
# 3            26  Driver & Passenger      Front  ...          6     193
# 4            30         Driver only       Rear  ...          4     186
# ..          ...                 ...        ...  ...        ...     ...
# 88           21                None      Front  ...          7     187
# 89           30                None      Front  ...          5     180
# 90           25                None      Front  ...          4     159
# 91           28         Driver only       Rear  ...          5     190
# 92           28  Driver & Passenger      Front  ...          5     184
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# 0         102     68           37           26.5          11.0    2705
# 1         115     71           38           30.0          15.0    3560
# 2         102     67           37           28.0          14.0    3375
# 3         106     70           37           31.0          17.0    3405
# 4         109     69           39           27.0          13.0    3640
# ..        ...    ...          ...            ...           ...     ...
# 88        115     72           38           34.0           NaN    3960
# 89        103     67           35           31.5          14.0    2985
# 90         97     66           36           26.0          15.0    2810
# 91        104     67           37           29.5          14.0    2985
# 92        105     69           38           30.0          15.0    3245
#
#      Origin                Make
# 0   non-USA       Acura Integra
# 1   non-USA        Acura Legend
# 2   non-USA             Audi 90
# 3   non-USA            Audi 100
# 4   non-USA            BMW 535i
# ..      ...                 ...
# 88  non-USA  Volkswagen Eurovan
# 89  non-USA   Volkswagen Passat
# 90  non-USA  Volkswagen Corrado
# 91  non-USA           Volvo 240
# 92  non-USA           Volvo 850
#
# [93 rows x 27 columns]

# %%
cars[['Length','Weight']]
# Out:
#     Length  Weight
# 0      177    2705
# 1      195    3560
# 2      180    3375
# 3      193    3405
# 4      186    3640
# ..     ...     ...
# 88     187    3960
# 89     180    2985
# 90     159    2810
# 91     190    2985
# 92     184    3245
#
# [93 rows x 2 columns]

# %%
plt.scatter(x=cars['Length'], y=cars['Weight'], c = 'r', s=50, alpha=0.1)
plt.show()

# %% [markdown]
# ## 산점도 함수 옵션
# ### 축이름, 그래프 제목
# - plt.xlabel('x축 이름')
# - plt.ylabel('y축 이름')
# - plt.title('그래프 제목', fontdict, loc, pad)
#     - fontdict 은 딕셔너리형태로 폰트에 대한 설정을 입력함
#         - fontsize 는 숫자단위를 입력하거나 'smaller', 'x-large' 등의 상대적인 설정 가능
#         - fontweight 는 'normal', 'bold', 'heavy', 'light', 'ultrabold', 'ultralight' 설정 가능
#     - loc는 위치. "left", "center", "right" 중 선택 가능
#     - pad는 타이틀과 그래프와의 간격(오프셋)을 포인트단위로 설정

# %% [markdown]
# __[예제]__
# Cars93의 Length와 Weight 변수에 대한 산점도에 제목과 축 이름을 지정하기

# %%
plt.title('Cars93', loc='right', pad=20) ## 오른쪽위 

title_font = {
    'fontsize':16,
    'fontweight': 'bold'
}

plt.scatter(x=cars['Length'], y=cars['Weight'], alpha=0.5)
plt.xlabel("Length")
plt.ylabel("Weight")
plt.title('Cars93', fontdict = title_font, loc='left', pad=20) ## 왼쪽 위 타이틀 
plt.show()

# %% [markdown]
# ## 좌표축 범위
# - plt.axis([xmin, xmax, ymin, ymax])
# - 입력값이 없으면 데이터에 맞게 자동으로 범위를 지정해줌

# %% [markdown]
# __[예제]__
# Cars93의 Length와 Weight 변수에 대해 각각 최솟값, 최댓값을 구하고 적절한 축 범위를 지정하여 산점도 그리기

# %%
# length와 weight의 범위 구하기
a, b = cars['Length'].min(), cars['Length'].max()
print("Length의 최소값: %d, 최댓값: %d"%(a, b))
print('\n')
c, d = cars['Weight'].min(), cars['Weight'].max()
print("Weight의 최소값: %d, 최댓값: %d"%(c, d))
# Out:
# Length의 최소값: 141, 최댓값: 219
#
#
# Weight의 최소값: 1695, 최댓값: 4105

# %%
# x축과 y축 범위를 지정하여 산점도 그리기
# x축 범위 (130, 230), y 축 범위 (1600, 4400)으로 지정

plt.scatter(x=cars['Length'], y=cars['Weight'], alpha=0.5)
plt.axis([0, 230, 0, 4400])

title_font = {
    'fontsize':20,
    'fontweight': 'bold'
}

plt.xlabel("Length")
plt.ylabel("Weight")
plt.title('Cars93', fontdict = title_font, loc='left', pad=20)
plt.show()

# %% [markdown]
# ## 산점도 활용

# %%
# 범주별로 색을 구분하기
groups = cars.groupby('AirBags')

fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.Length,
           group.Weight,
            marker='o',
           linestyle='',
           label=name)


    
ax.legend(fontsize=9.5, loc='upper left')
plt.title('Scatter Plot by Groups', fontsize=20)
plt.xlabel('Length'); plt.ylabel('Weight')
plt.show()

# %%
groups.mean()
# Out:
#                     Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# AirBags
# Driver & Passenger  24.781250  28.368750  31.962500  19.562500    27.125000
# Driver only         18.709302  21.223256  23.739535  21.627907    28.418605
# None                11.520588  13.173529  14.835294  24.617647    30.852941
#
#                     EngineSize  Horsepower          RPM  Rev.per.mile  \
# AirBags
# Driver & Passenger    3.281250  184.062500  5325.000000   2141.875000
# Driver only           2.839535  151.790698  5205.813953   2224.418605
# None                  2.161765  114.823529  5354.411765   2558.088235
#
#                     Fuel.tank.capacity  Passengers      Length   Wheelbase  \
# AirBags
# Driver & Passenger           18.112500    5.125000  193.250000  108.062500
# Driver only                  17.130233    5.046512  185.418605  104.767442
# None                         15.394118    5.117647  175.676471  100.970588
#
#                         Width  Turn.circle  Rear.seat.room  Luggage.room  \
# AirBags
# Driver & Passenger  71.875000    40.625000       28.687500     14.750000
# Driver only         69.860465    39.790698       27.780488     14.500000
# None                67.588235    37.117647       27.485294     12.571429
#
#                          Weight
# AirBags
# Driver & Passenger  3431.562500
# Driver only         3177.790698
# None                2771.470588

# %%
# 범주별로 색과 스타일을 구분하기
import seaborn as sns

sns.scatterplot(x='Length',
               y='Weight',
               hue='AirBags',  #범주별로 색을 다르게지정하겠다는 뜻
               style='AirBags', #범주별로 스타일을 다르게 지정하겠다는 뜻
               s=50,
               data=cars)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c2c099c70fe> in <module>
#       7                style='AirBags', #범주별로 스타일을 다르게 지정하겠다는 뜻
#       8                s=50,
# ----> 9                data=cars)
#      10 plt.show()
#
# NameError: name 'cars' is not defined

# %%
import seaborn as sns
import pandas as pd 
iris = pd.read_csv('../../data/iris.csv')

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width          target
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='petal length',
               y='petal width',
               hue='target',  #범주별로 색을 다르게지정하겠다는 뜻
               style='target', #범주별로 스타일을 다르게 지정하겠다는 뜻
               s=50,
               data=iris)
