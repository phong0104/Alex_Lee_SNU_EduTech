# %% [markdown]
# ### 3절. 이상치 인식
# #### 1. 사분위수
# * 데이터명.describe()
#     * 결측치가 아닌 데이터행의 개수
#     * 평균/표준편차
#     * 최소/최댓값
#     * Q1, Q2, Q3 나타내줌
# * IQR을 이용한 이상치 탐색 : 함수 생성
# ![python image2](https://blog.kakaocdn.net/dn/cAqc6V/btqyQLiddUd/iXQVu1nYTo2rx3Q8xZBqy0/img.png)

# %%
import pandas as pd 
import numpy as np

# %%
air = pd.read_csv('../data/airquality.csv')
print(air.head())
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %%
air
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 148   30.0    193.0   6.9    70      9   26
# 149    NaN    145.0  13.2    77      9   27
# 150   14.0    191.0  14.3    75      9   28
# 151   18.0    131.0   8.0    76      9   29
# 152   20.0    223.0  11.5    68      9   30
#
# [153 rows x 6 columns]

# %%
# Ozone 변수에서 이상치를 박스플롯으로 확인
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Ozone', data=air)
plt.show()

# %%
# IQR 을 이용한 이상치 탐색 함수

def detect_outliers(df=None, column=None, weight=1.5):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    
    IQR = Q3 - Q1
    IQR_weight = IQR*weight
    
    outlier_idx = df[(df[column] < Q1 - IQR_weight) | (df[column] > Q3 + IQR_weight)].index
    
    return outlier_idx

# %%
out_index = detect_outliers(df=air, column='Ozone')

# %%
air.loc[out_index,'outlier']=True

# %%
air[air['outlier']==True]
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day outlier
# 61   135.0    269.0   4.1    84      7    1    True
# 116  168.0    238.0   3.4    81      8   25    True

# %%
Outliers_to_drop = detect_outliers(df=air, column='Ozone', weight=1.5)

# %%
# IQR로 이상치를 찾아 인덱스 저장
Outliers_to_drop
# Out:
# Int64Index([61, 116], dtype='int64')

# %%
# Ozone 변수에서 outliers 가 있었던 데이터 확인
air.loc[Outliers_to_drop]
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day outlier
# 61   135.0    269.0   4.1    84      7    1    True
# 116  168.0    238.0   3.4    81      8   25    True

# %%
# outlier 제거한 데이터
air_2 = air.drop(Outliers_to_drop, axis=0).reset_index(drop=True)

# %%
# %pwd
# Out:
# 'E:\\01.jupyter\\ADP실기_book\\3. EDA를 위한 그래프 그리기\\boxplot'

# %%
df_t = pd.read_csv('../data/titanic.csv')

# %%
df_t.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df_t.embark_town
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
df_t[df_t.embark_town.duplicated()!=True]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 5          0       3    male   NaN      0      0   8.4583        Q  Third
# 61         1       1  female  38.0      0      0  80.0000      NaN  First
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 1   woman       False    C    Cherbourg   yes  False
# 5     man        True  NaN   Queenstown    no   True
# 61  woman       False    B          NaN   yes   True

# %%
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df_t['구분'] = 0

# %%
df_t.loc[i,'embark_town']
# Out:
# 'Cherbourg'

# %%
for i in range(len(df_t)-1): 
    if df_t.loc[i,'age'] == np.na
        for j in range(5) : 
            df_t.loc[i-j,'보간치'] = df_t.loc[i-j,'보간치']
        for j in range(5) : 
            df_t.loc[i+j,'보간치'] = df_t.loc[i+j,'보간치']

# %%
df_t.head(100)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 95         0       3    male   NaN      0      0   8.0500        S   Third
# 96         0       1    male  71.0      0      0  34.6542        C   First
# 97         1       1    male  23.0      0      1  63.3583        C   First
# 98         1       2  female  34.0      0      1  23.0000        S  Second
# 99         0       2    male  34.0      1      0  26.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone  구분
# 0     man        True  NaN  Southampton    no  False   0
# 1   woman       False    C    Cherbourg   yes  False   0
# 2   woman       False  NaN  Southampton   yes   True   1
# 3   woman       False    C  Southampton   yes  False   1
# 4     man        True  NaN  Southampton    no   True   0
# ..    ...         ...  ...          ...   ...    ...  ..
# 95    man        True  NaN  Southampton    no   True   0
# 96    man        True    A    Cherbourg    no   True   1
# 97    man        True    D    Cherbourg   yes  False   0
# 98  woman       False  NaN  Southampton   yes  False   1
# 99    man        True  NaN  Southampton    no  False   1
#
# [100 rows x 16 columns]
