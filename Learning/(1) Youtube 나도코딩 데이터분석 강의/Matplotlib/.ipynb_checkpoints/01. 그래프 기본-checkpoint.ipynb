# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000002325C1648E0>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title("꺾은선")
# Out:
# Text(0.5, 1.0, '꺾은선')
# C:\Users\phong\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\phong\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\phong\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\phong\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\phong\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\phong\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자 깨짐 현상 해결

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXGeneral',
#  'cmss10',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'cmex10',
#  'STIXGeneral',
#  'cmb10',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'cmsy10',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'cmmi10',
#  'DejaVu Serif Display',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'cmtt10',
#  'DejaVu Sans Display',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'HCR Dotum',
#  'Cambria',
#  'Calibri',
#  'Georgia',
#  'Courier New',
#  'Marlett',
#  'Calibri',
#  'Yu Gothic',
#  'Symbol',
#  'Microsoft Sans Serif',
#  'Han Santteut Dotum',
#  'Comic Sans MS',
#  'Trebuchet MS',
#  'HCR Batang ExtB',
#  'Microsoft Himalaya',
#  'MS Gothic',
#  'Corbel',
#  'Gadugi',
#  'Microsoft JhengHei',
#  'Microsoft New Tai Lue',
#  'Nirmala UI',
#  'Verdana',
#  'Courier New',
#  'HCR Dotum',
#  'Ink Free',
#  'Verdana',
#  'HCR Dotum',
#  'Candara',
#  'HCR Batang Ext',
#  'Segoe UI Symbol',
#  'Microsoft PhagsPa',
#  'Calibri',
#  'Corbel',
#  'Candara',
#  'Gulim',
#  'Courier New',
#  'Courier New',
#  'D2Coding ligature',
#  'Corbel',
#  'Verdana',
#  'Yu Gothic',
#  'Sitka Small',
#  'Nirmala UI',
#  'SimSun-ExtB',
#  'Microsoft Yi Baiti',
#  'Segoe UI',
#  'Cambria',
#  'Corbel',
#  'Segoe Print',
#  'Palatino Linotype',
#  'Myanmar Text',
#  'Segoe UI',
#  'Microsoft New Tai Lue',
#  'Calibri',
#  'Franklin Gothic Medium',
#  'Segoe UI',
#  'D2Coding ligature',
#  'Gabriola',
#  'HCR Batang ExtB',
#  'Symbol',
#  'Trebuchet MS',
#  'Palatino Linotype',
#  'Sitka Small',
#  'Microsoft Tai Le',
#  'Mongolian Baiti',
#  'HCR Dotum Ext',
#  'HCR Batang',
#  'HyhwpEQ',
#  'Palatino Linotype',
#  'Malgun Gothic',
#  'Arial',
#  'Lucida Sans Unicode',
#  'Verdana',
#  'HancomEQN',
#  'Wingdings',
#  'Hancom Gothic',
#  'Verdana',
#  'Segoe Script',
#  'Consolas',
#  'Consolas',
#  'MV Boli',
#  'Times New Roman',
#  'Segoe Script',
#  'Microsoft YaHei',
#  'Cambria',
#  'Georgia',
#  'Segoe MDL2 Assets',
#  'SimSun',
#  'NewJumja',
#  'NewJumja',
#  'Segoe Print',
#  'Segoe UI',
#  'D2Coding',
#  'Verdana',
#  'Microsoft New Tai Lue',
#  'Trebuchet MS',
#  'Malgun Gothic',
#  'Segoe UI Emoji',
#  'HoloLens MDL2 Assets',
#  'Leelawadee UI',
#  'Calibri',
#  'Microsoft JhengHei',
#  'Sitka Small',
#  'Ebrima',
#  'NanumGothic',
#  'Ink Free',
#  'Microsoft Sans Serif',
#  'Segoe UI',
#  'Sylfaen',
#  'MingLiU-ExtB',
#  'HoloLens MDL2 Assets',
#  'Segoe UI',
#  'NanumGothic',
#  'Leelawadee UI',
#  'Verdana',
#  'Microsoft Yi Baiti',
#  'Corbel',
#  'Leelawadee UI',
#  'MingLiU-ExtB',
#  'Comic Sans MS',
#  'Georgia',
#  'Times New Roman',
#  'Cambria',
#  'HCR Batang ExtB',
#  'Leelawadee UI',
#  'Malgun Gothic',
#  'Yu Gothic',
#  'Leelawadee UI',
#  'Trebuchet MS',
#  'Arial',
#  'Microsoft YaHei',
#  'Candara',
#  'Microsoft Tai Le',
#  'Sitka Small',
#  'Georgia',
#  'Bahnschrift',
#  'Tahoma',
#  'Nirmala UI',
#  'Ebrima',
#  'Candara',
#  'Comic Sans MS',
#  'Comic Sans MS',
#  'Corbel',
#  'Corbel',
#  'Microsoft Tai Le',
#  'Segoe Script',
#  'Arial',
#  'Segoe Print',
#  'Segoe UI',
#  'Segoe UI Symbol',
#  'Constantia',
#  'Nirmala UI',
#  'Corbel',
#  'Times New Roman',
#  'Tahoma',
#  'D2Coding ligature',
#  'Cambria',
#  'Lucida Console',
#  'Microsoft JhengHei',
#  'Georgia',
#  'Times New Roman',
#  'Microsoft YaHei',
#  'Times New Roman',
#  'Batang',
#  'Microsoft JhengHei',
#  'Sitka Small',
#  'Han Santteut Dotum',
#  'Hancom Gothic',
#  'Calibri',
#  'MS Gothic',
#  'Times New Roman',
#  'Segoe UI',
#  'Sylfaen',
#  'Arial',
#  'Times New Roman',
#  'Candara',
#  'Georgia',
#  'Courier New',
#  'Microsoft New Tai Lue',
#  'Constantia',
#  'Consolas',
#  'Segoe UI',
#  'Myanmar Text',
#  'Segoe UI',
#  'Segoe UI',
#  'Candara',
#  'Microsoft JhengHei',
#  'Consolas',
#  'Segoe UI',
#  'Impact',
#  'Candara',
#  'Tahoma',
#  'HCR Dotum Ext',
#  'Yu Gothic',
#  'Segoe Print',
#  'Arial',
#  'Calibri',
#  'Trebuchet MS',
#  'Constantia',
#  'Segoe MDL2 Assets',
#  'Consolas',
#  'Calibri',
#  'Palatino Linotype',
#  'Segoe UI',
#  'Constantia',
#  'Sitka Small',
#  'HyhwpEQ',
#  'Courier New',
#  'Franklin Gothic Medium',
#  'Segoe UI',
#  'Corbel',
#  'Microsoft Himalaya',
#  'Segoe UI',
#  'Cambria',
#  'Franklin Gothic Medium',
#  'Webdings',
#  'Yu Gothic',
#  'Candara',
#  'Trebuchet MS',
#  'Cambria',
#  'Segoe UI',
#  'Trebuchet MS',
#  'Hancom Gothic',
#  'Consolas',
#  'HCR Batang',
#  'Corbel',
#  'Leelawadee UI',
#  'Gadugi',
#  'Gadugi',
#  'Corbel',
#  'SimSun',
#  'Verdana',
#  'Yu Gothic',
#  'Nirmala UI',
#  'Javanese Text',
#  'Gabriola',
#  'Segoe UI Emoji',
#  'Mongolian Baiti',
#  'Microsoft PhagsPa',
#  'Arial',
#  'Consolas',
#  'HCR Batang',
#  'Arial',
#  'Ebrima',
#  'Palatino Linotype',
#  'Nirmala UI',
#  'D2Coding',
#  'Constantia',
#  'Microsoft JhengHei',
#  'Segoe UI',
#  'Han Santteut Dotum',
#  'Palatino Linotype',
#  'Myanmar Text',
#  'Consolas',
#  'Impact',
#  'Arial',
#  'Yu Gothic',
#  'D2Coding',
#  'HCR Batang ExtB',
#  'Courier New',
#  'Segoe UI Historic',
#  'Ebrima',
#  'Malgun Gothic',
#  'Webdings',
#  'Yu Gothic',
#  'Calibri',
#  'Candara',
#  'Arial',
#  'Calibri',
#  'Bahnschrift',
#  'Segoe UI Historic',
#  'Comic Sans MS',
#  'Malgun Gothic',
#  'Han Santteut Dotum',
#  'SimSun-ExtB',
#  'Constantia',
#  'Constantia',
#  'Microsoft YaHei',
#  'HCR Batang',
#  'Batang',
#  'Georgia',
#  'Candara',
#  'Tahoma',
#  'HancomEQN',
#  'Microsoft PhagsPa',
#  'Lucida Console',
#  'Trebuchet MS',
#  'Cambria',
#  'Haan Wing2',
#  'HCR Batang Ext',
#  'Segoe UI',
#  'Georgia',
#  'Myanmar Text',
#  'Candara',
#  'Constantia',
#  'Arial',
#  'Microsoft PhagsPa',
#  'Franklin Gothic Medium',
#  'D2Coding',
#  'Javanese Text',
#  'Corbel',
#  'Times New Roman',
#  'Calibri',
#  'Segoe UI',
#  'Microsoft YaHei',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Microsoft YaHei',
#  'Comic Sans MS',
#  'Courier New',
#  'Palatino Linotype',
#  'Palatino Linotype',
#  'Hancom Gothic',
#  'Wingdings',
#  'Segoe UI',
#  'Segoe Script',
#  'Candara',
#  'Microsoft Tai Le',
#  'Lucida Sans Unicode',
#  'Sitka Small',
#  'Segoe UI',
#  'Sitka Small',
#  'Segoe UI',
#  'Gulim',
#  'Haan Wing2',
#  'Malgun Gothic',
#  'Segoe UI',
#  'HCR Dotum',
#  'MV Boli',
#  'Comic Sans MS',
#  'Gadugi',
#  'Calibri']

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
